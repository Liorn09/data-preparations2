# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("labs/DS0105EN/5000 Sales Records.csv")

# %%
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# ## I prefer to convert the column headings to uppercase, so I'll do that below.

# %%
df.columns.str.upper()
# Out:
# Index(['REGION', 'COUNTRY', 'ITEM TYPE', 'SALES CHANNEL', 'ORDER PRIORITY',
#        'ORDER DATE', 'ORDER ID', 'SHIP DATE', 'UNITS SOLD', 'UNIT PRICE',
#        'UNIT COST', 'TOTAL REVENUE', 'TOTAL COST', 'TOTAL PROFIT'],
#       dtype='object')

# %%
df.columns= df.columns.str.upper()

# %% [markdown]
# lets see what we have now,

# %%
df.head()
# Out:
#                               REGION               COUNTRY  ITEM TYPE  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   SALES CHANNEL ORDER PRIORITY  ORDER DATE   ORDER ID  SHIP DATE  UNITS SOLD  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    UNIT PRICE  UNIT COST  TOTAL REVENUE  TOTAL COST  TOTAL PROFIT
# ...

# %% [markdown]
# Replace space in the headings with underscore

# %%
df.columns=df.columns.str.replace(' ', '_')

# %% [markdown]
# We now have to search for missing data

# %%
df.isnull()
# Out:
#       REGION  COUNTRY  ITEM_TYPE  SALES_CHANNEL  ORDER_PRIORITY  ORDER_DATE  \
# 0      False    False      False          False           False       False
# 1      False    False      False          False           False       False
# 2      False    False      False          False           False       False
# 3      False    False      False          False           False       False
# 4      False    False      False          False           False       False
# ...      ...      ...        ...            ...             ...         ...
# 4995   False    False      False          False           False       False
# 4996   False    False      False          False           False       False
# 4997   False    False      False          False           False       False
# 4998   False    False      False          False           False       False
# 4999   False    False      False          False           False       False
#
# ...

# %%
df.isnull().sum()
# Out:
# REGION            0
# COUNTRY           0
# ITEM_TYPE         0
# SALES_CHANNEL     0
# ORDER_PRIORITY    0
# ORDER_DATE        0
# ORDER_ID          0
# SHIP_DATE         0
# UNITS_SOLD        0
# UNIT_PRICE        0
# UNIT_COST         0
# TOTAL_REVENUE     0
# TOTAL_COST        0
# TOTAL_PROFIT      0
# dtype: int64

# %% [markdown]
# lets do some plottings

# %%
from matplotlib import pyplot as plt

# %%
df.columns[12]
# Out:
# 'TOTAL_COST'

# %%
Ukraine= df[df.COUNTRY == 'Ukraine']

# %%
Ukraine
# Out:
#       REGION  COUNTRY        ITEM_TYPE SALES_CHANNEL ORDER_PRIORITY  \
# 84    Europe  Ukraine        Cosmetics        Online              H
# 113   Europe  Ukraine    Personal Care        Online              M
# 620   Europe  Ukraine        Cosmetics        Online              C
# 647   Europe  Ukraine           Snacks       Offline              C
# 910   Europe  Ukraine  Office Supplies       Offline              M
# 1138  Europe  Ukraine       Vegetables        Online              C
# 1148  Europe  Ukraine          Clothes       Offline              H
# 1296  Europe  Ukraine        Household        Online              H
# 1491  Europe  Ukraine             Meat       Offline              H
# 1842  Europe  Ukraine        Cosmetics        Online              C
# 1846  Europe  Ukraine           Cereal       Offline              C
# 1939  Europe  Ukraine        Beverages        Online              H
# 2082  Europe  Ukraine        Cosmetics        Online              L
# ...

# %%
Armenia= df[df.COUNTRY == 'Armenia']

# %%
Armenia
# Out:
#       REGION  COUNTRY        ITEM_TYPE SALES_CHANNEL ORDER_PRIORITY  \
# 137   Europe  Armenia           Fruits        Online              M
# 477   Europe  Armenia           Cereal        Online              H
# 510   Europe  Armenia       Vegetables        Online              M
# 560   Europe  Armenia             Meat        Online              L
# 810   Europe  Armenia           Fruits       Offline              L
# 921   Europe  Armenia        Baby Food       Offline              H
# 946   Europe  Armenia    Personal Care        Online              C
# 1389  Europe  Armenia             Meat       Offline              M
# 1487  Europe  Armenia        Household       Offline              M
# 1683  Europe  Armenia           Snacks       Offline              L
# 2057  Europe  Armenia    Personal Care        Online              C
# 2070  Europe  Armenia           Cereal       Offline              H
# 2207  Europe  Armenia             Meat       Offline              C
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(Ukraine.UNITS_SOLD, Ukraine.TOTAL_COST/10**6, 'o')
plt.plot(Armenia.UNITS_SOLD, Armenia.TOTAL_COST/10**6, 'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The total cost is in millions

# %% [markdown]
# It is seen that the total cost increases with the units sold from the scattered plot shown

# %% [markdown]
# Now lets add labels

# %%
plt.plot(Ukraine.UNITS_SOLD, Ukraine.TOTAL_COST/10**6, 'o')
plt.plot(Armenia.UNITS_SOLD, Armenia.TOTAL_COST/10**6, 'o')
plt.show
plt.xlabel('UNITS SOLD')
plt.ylabel('TOTAL COST')
# Out:
# Text(0, 0.5, 'TOTAL COST')
